# %%
# !lscpu
# Out:
# Architecture:             x86_64
#   CPU op-mode(s):         32-bit, 64-bit
#   Address sizes:          39 bits physical, 48 bits virtual
#   Byte Order:             Little Endian
# CPU(s):                   16
#   On-line CPU(s) list:    0-15
# Vendor ID:                GenuineIntel
#   Model name:             12th Gen Intel(R) Core(TM) i5-12500H
#     CPU family:           6
#     Model:                154
#     Thread(s) per core:   2
#     Core(s) per socket:   8
#     Socket(s):            1
#     Stepping:             3
#     BogoMIPS:             6220.79
#     Flags:                fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge m
#                           ca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht sysc
#                           all nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xt
#                           opology tsc_reliable nonstop_tsc cpuid pni pclmulqdq v
#                           mx ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popc
# ...

# %%
# !gcc sumaVectoresSecuencial.c -o sumaVectoresSecuencial
# !./sumaVectoresSecuencial 10000000000
# Out:
# Asignando memoria para el arreglo A
# Asignando memoria para el arreglo B
# Asignando memoria para el arreglo C
# Inicializando los arreglos A y B con números aleatorios
# Sumando los elementos de los arreglos A y B
# El tiempo de ejecución es de: 4.699160 segundos
# Bad pipe message: %s [b'"Chromium";v="134", "Not:A-Brand";v="24", "Microsoft Edge']
# Bad pipe message: %s [b'v="134"\r\nsec-ch-ua-mobile: ?0\r\nse', b'ch-ua-platform: "Windows"\r\nUpgrade-Insecure-Requests: 1\r\nUser-Agent: Mozilla/5.0 (Windows NT 10.0;', b'in64; x64) AppleWebKit/537.36 (', b'TML, like Gecko) Chrome/134.0.0.0 Safari/537.36 Edg/134.0.0.0\r\nAccept: tex']
# Bad pipe message: %s [b'html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exch', b'ge;v=b3;q=0.7\r\nSec-Fetch-Site: none\r\nSec-Fetch-Mode: navigate\r\nSec-Fetch-User: ?1\r\nSec-Fetch-Des']
# ...
